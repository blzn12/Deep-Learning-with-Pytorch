# %%
# !pip install datasets spacy
# !python -m spacy download en_core-web_sm
# Out:
# ...
#
# ✘ No compatible package found for 'en_core' (spaCy v3.8.7)

# %%
from datasets import load_dataset
import spacy
import re
